# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt


ppath = 'C:\\Users\\shahr\\code\\GPF_Qazi\\Nicholas\\'

#final_v2 = pd.read_csv(f'{ppath}final.csv')
final_raw = pd.read_csv(f'{ppath}final_df_without_standardize.csv')
final_df3 = pd.read_csv(f'{ppath}final_df3.csv')


final_raw.head()
# Out:
#    userid   idnumber NO_MATRIK_LAMA  number_of_courses  total_marks  \
# 0      64  WIF160010      WIF160010                6.0       362.90
# 1      65  WIF160052      WIF160052                6.0       321.90
# 2      66  WIE160015      WIE160015                7.0       472.60
# 3      67  WIC160061      WIC160061                6.0       429.40
# 4      68  WIC160008      WIC160008                7.0       600.48
#
#    total_login  weekend_login  weekday_login  midnight_login  \
# 0        168.0           24.0          144.0            43.0
# 1         88.0            5.0           83.0            29.0
# 2        147.0           24.0          123.0            63.0
# 3        115.0           15.0          100.0            38.0
# 4        203.0           35.0          168.0            85.0
#
#    early_morning_login  ...  night_login  no_of_viewed_courses  \
# 0                 33.0  ...          9.0                1282.0
# ...

# %%
final_raw.columns
# Out:
# Index(['userid', 'idnumber', 'NO_MATRIK_LAMA', 'number_of_courses',
#        'total_marks', 'total_login', 'weekend_login', 'weekday_login',
#        'midnight_login', 'early_morning_login', 'late_morning_login',
#        'afternoon_login', 'evening_login', 'night_login',
#        'no_of_viewed_courses', 'no_of_attendance_taken',
#        'no_of_all_files_downloaded', 'no_of_assignments',
#        'no_of_forum_created', 'number_of_quizzes', 'no_of_quizzes_completed',
#        'no_of_quizzes_attempt', 'f_quizzes_giveup'],
#       dtype='object')

# %%
final_df3.info()
final_df3.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18576 entries, 0 to 18575
# Data columns (total 21 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   userid                      18576 non-null  float64
#  1   number_of_courses           18576 non-null  float64
#  2   total_marks                 18576 non-null  float64
#  3   total_login                 18576 non-null  float64
#  4   weekend_login               18576 non-null  float64
#  5   weekday_login               18576 non-null  float64
#  6   midnight_login              18576 non-null  float64
#  7   early_morning_login         18576 non-null  float64
#  8   late_morning_login          18576 non-null  float64
#  9   afternoon_login             18576 non-null  float64
#  10  evening_login               18576 non-null  float64
#  11  night_login                 18576 non-null  float64
#  12  no_of_viewed_courses        18576 non-null  float64
# ...

# %%
final_df3.columns
# Out:
# Index(['userid', 'number_of_courses', 'total_marks', 'total_login',
#        'weekend_login', 'weekday_login', 'midnight_login',
#        'early_morning_login', 'late_morning_login', 'afternoon_login',
#        'evening_login', 'night_login', 'no_of_viewed_courses',
#        'no_of_attendance_taken', 'no_of_all_files_downloaded',
#        'no_of_assignments', 'no_of_forum_created', 'number_of_quizzes',
#        'no_of_quizzes_completed', 'no_of_quizzes_attempt', 'f_quizzes_giveup'],
#       dtype='object')

# %%
final_short = final_raw.copy()
final_short.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18576 entries, 0 to 18575
# Data columns (total 23 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   userid                      18576 non-null  int64
#  1   idnumber                    18576 non-null  object
#  2   NO_MATRIK_LAMA              18576 non-null  object
#  3   number_of_courses           18576 non-null  float64
#  4   total_marks                 18576 non-null  float64
#  5   total_login                 18576 non-null  float64
#  6   weekend_login               18576 non-null  float64
#  7   weekday_login               18576 non-null  float64
#  8   midnight_login              18576 non-null  float64
#  9   early_morning_login         18576 non-null  float64
#  10  late_morning_login          18576 non-null  float64
#  11  afternoon_login             18576 non-null  float64
#  12  evening_login               18576 non-null  float64
# ...

# %%
#final_raw['number_of_courses'].hist()

'''
final_short = final_raw.copy()
final_short = final_short.drop(['userid','idnumber','NO_MATRIK_LAMA'],axis=1)
for col in final_short.columns:
    final_short[col].plot.box(logy=True)
    plt.show()
'''

final_short = final_raw.copy()

fig, axes = plt.subplots(nrows=5, ncols=5, figsize=(20,20))
count = 0
for col in [x for x in final_short.select_dtypes(include=["float"]).columns if x != "userid"]:
    i, j = count // 5, count % 5
    final_short[col].value_counts().plot(kind="hist", ax=axes[i, j],logy=True)


    axes[i,j].set_title(col)
    count+=1
fig.tight_layout(pad=2.0)
fig.show()
# Out:
# C:\Users\shahr\AppData\Local\Temp\ipykernel_84\3162324120.py:23: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
